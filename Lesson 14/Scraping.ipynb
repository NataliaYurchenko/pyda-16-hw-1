# %%
import requests

# %%
URL = 'https://habr.com/ru/all'
KEYWORDS = ['python', 'парсинг']
params = {
    'search_query': KEYWORDS
}

# %%
res = requests.get(URL, params)

# %%
res.text
# Out:
# '<!DOCTYPE html>\n<html lang="ru" class="no-js">\n  <head>\n    <meta http-equiv="content-type" content="text/html; charset=utf-8" />\n<meta content=\'width=1024\' name=\'viewport\'>\n<title>Все публикации подряд / Хабр</title>\n\n\n\n  <meta property="fb:app_id" content="444736788986613" />\n<meta property="og:type" content="website"/>\n<meta property="fb:pages" content="472597926099084"/>\n<meta property="og:site_name" content="Хабр" />\n<link rel="image_src" href="https://habrastorage.org/storage/stuff/habr/habr_ru.png" />\n<meta property="og:image" content="https://habrastorage.org/storage/stuff/habr/habr_ru.png" />\n<meta property="og:image:width" content="1200" />\n<meta property="og:image:height" content="628" />\n<meta property="og:title" content="Все публикации подряд / Хабр"/>\n<meta property="og:description" content="Хабр — крупнейший в Европе ресурс для IT-специалистов. Сюда приходят обсудить новости индустрии и поделиться опытом."/>\n\n\n\n<meta name=\'yandex-verificatio
# ...

# %%
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(res.text, 'html.parser')
soup
# Out:
# <!DOCTYPE html>
#
# <html class="no-js" lang="ru">
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
# <meta content="width=1024" name="viewport"/>
# <title>Все публикации подряд / Хабр</title>
# <meta content="444736788986613" property="fb:app_id">
# <meta content="website" property="og:type"/>
# <meta content="472597926099084" property="fb:pages"/>
# <meta content="Хабр" property="og:site_name"/>
# <link href="https://habrastorage.org/storage/stuff/habr/habr_ru.png" rel="image_src"/>
# <meta content="https://habrastorage.org/storage/stuff/habr/habr_ru.png" property="og:image"/>
# <meta content="1200" property="og:image:width"/>
# <meta content="628" property="og:image:height"/>
# <meta content="Все публикации подряд / Хабр" property="og:title"/>
# <meta content="Хабр — крупнейший в Европе ресурс для IT-специалистов. Сюда приходят обсудить новости индустрии и поделиться опытом." property="og:description"/>
# ...

# %%
news_blocks = soup.find_all('div', class_='news-topic')  
news_blocks
# Out:
# [<div class="news-topic">
#  <a class="news-topic__title" href="https://habr.com/ru/news/t/544518/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'tm_block', 'news', 'title'); }">Mozilla опровергла слухи об исчезновении лисы из логотипа Firefox</a>
#  <div class="news-topic__attrs">
#  <span class="news-topic__attr news-topic__attr_date-time">16:16</span>
#  <a class="news-topic__attr news-topic__attr_comments" href="https://habr.com/ru/news/t/544518/#comments" onclick="if (typeof ga === 'function') { ga('send', 'event', 'tm_block', 'news', 'comments'); }">Комментарии: 0</a>
#  </div>
#  </div>,
#  <div class="news-topic">
#  <a class="news-topic__title" href="https://habr.com/ru/news/t/544502/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'tm_block', 'news', 'title'); }">Red Hat предложит бесплатные подписки на RHEL некоторым организациям открытого ПО</a>
#  <div class="news-topic__attrs">
# ...

# %%
articles_intro = list(map(lambda x: x.find('div', class_='news-topic__attrs'), news_blocks))
articles_intro
# Out:
# [<div class="news-topic__attrs">
#  <span class="news-topic__attr news-topic__attr_date-time">16:16</span>
#  <a class="news-topic__attr news-topic__attr_comments" href="https://habr.com/ru/news/t/544518/#comments" onclick="if (typeof ga === 'function') { ga('send', 'event', 'tm_block', 'news', 'comments'); }">Комментарии: 0</a>
#  </div>,
#  <div class="news-topic__attrs">
#  <span class="news-topic__attr news-topic__attr_date-time">13:34</span>
#  <a class="news-topic__attr news-topic__attr_comments" href="https://habr.com/ru/news/t/544502/#comments" onclick="if (typeof ga === 'function') { ga('send', 'event', 'tm_block', 'news', 'comments'); }">Комментарии: 1</a>
#  </div>,
#  <div class="news-topic__attrs">
#  <span class="news-topic__attr news-topic__attr_date-time">13:01</span>
# ...

# %%
a_list = list(map(lambda x: x.find('a').get('href'), articles_intro))
a_list
# Out:
# ['https://habr.com/ru/news/t/544518/#comments',
#  'https://habr.com/ru/news/t/544502/#comments',
#  'https://habr.com/ru/news/t/544496/#comments',
#  'https://habr.com/ru/news/t/544484/#comments',
#  'https://habr.com/ru/news/t/544482/#comments',
#  'https://habr.com/ru/news/t/544480/#comments',
#  'https://habr.com/ru/news/t/544468/#comments',
#  'https://habr.com/ru/news/t/544462/#comments',
#  'https://habr.com/ru/news/t/544452/#comments',
#  'https://habr.com/ru/news/t/544418/#comments']

# %%
def get_all_links(url, query):
    
    params = {
    'search_query': KEYWORDS
}
    res = requests.get(URL, params)
    soup = BeautifulSoup(res.text, 'html.parser')
    news_blocks = soup.find_all('div', class_='news-topic') 
    articles_intro = list(map(lambda x: x.find('div', class_='news-topic__attrs'), news_blocks))
    a_list = list(map(lambda x: x.find('a').get('href'), articles_intro))
    

    return a_list

all_links = get_all_links(URL, KEYWORDS)
all_links
# Out:
# ['https://habr.com/ru/news/t/544526/#comments',
#  'https://habr.com/ru/news/t/544518/#comments',
#  'https://habr.com/ru/news/t/544502/#comments',
#  'https://habr.com/ru/news/t/544496/#comments',
#  'https://habr.com/ru/news/t/544484/#comments',
#  'https://habr.com/ru/news/t/544482/#comments',
#  'https://habr.com/ru/news/t/544480/#comments',
#  'https://habr.com/ru/news/t/544468/#comments',
#  'https://habr.com/ru/news/t/544462/#comments',
#  'https://habr.com/ru/news/t/544452/#comments']

# %%
import pandas as pd

# %%
for link in all_links:
    soup = BeautifulSoup(requests.get(link).text, 'html.parser')
    date = pd.to_datetime(soup.find('span', class_='post__time').get('data-time_published'), dayfirst=True).date()
    print(date)
    title = soup.find('h1', class_='post__title').text
    print(title)
    #text = soup.find('div', class_='article_text_wrapper').text
    print(link)
# Out:
# 2021-02-27
#
# Twitch удаляет антипрофсоюзную рекламу Amazon
#
# https://habr.com/ru/news/t/544526/#comments
# 2021-02-27
#
# Mozilla опровергла слухи об исчезновении лисы из логотипа Firefox
#
# https://habr.com/ru/news/t/544518/#comments
# 2021-02-27
#
# Red Hat предложит бесплатные подписки на RHEL некоторым организациям открытого ПО
#
# https://habr.com/ru/news/t/544502/#comments
# 2021-02-27
#
# Apple попросила разработчиков вернуть DTK с чипом A12Z до 31 марта 2021 года, через 9 месяцев, вместо 12 арендных
#
# https://habr.com/ru/news/t/544496/#comments
# 2021-02-27
#
# Функция базового Google TV превратит умный телевизор в обычный
#
# https://habr.com/ru/news/t/544484/#comments
# 2021-02-27
#
# Еще три военных. Запуски года: 15 всего, 5 от Китая
#
# https://habr.com/ru/news/t/544482/#comments
# 2021-02-27
#
# Грузовой корабль для МКС. 2020 год: 14 всего, 8 от США
#
# https://habr.com/ru/news/t/544480/#comments
# 2021-02-26
#
# ...

# %%
def get_habr_news(all_links):
    habr_news = pd.DataFrame()
    for link in all_links:
        soup = BeautifulSoup(requests.get(link).text, 'html.parser')
        if soup.find('span', class_='post__time'):
            date = pd.to_datetime(soup.find('span', class_='post__time').get('data-time_published'), dayfirst=True).date()
        if soup.find('h1', class_='post__title'): 
            title = soup.find('h1', class_='post__title').text    
        row = {'date': date, 'title': title, 'link': link}
        habr_news = pd.concat([habr_news, pd.DataFrame([row])])  
    return habr_news

# %%
get_habr_news(all_links)
# Out:
#          date                                              title  \
# 0  2021-02-27  \nTwitch удаляет антипрофсоюзную рекламу Amazon\n
# 0  2021-02-27  \nMozilla опровергла слухи об исчезновении лис...
# 0  2021-02-27  \nRed Hat предложит бесплатные подписки на RHE...
# 0  2021-02-27  \nApple попросила разработчиков вернуть DTK с ...
# 0  2021-02-27  \nФункция базового Google TV превратит умный т...
# 0  2021-02-27  \nЕще три военных. Запуски года: 15 всего, 5 о...
# 0  2021-02-27  \nГрузовой корабль для МКС. 2020 год: 14 всего...
# 0  2021-02-26  \nТорговая сеть DNS распродала все карты RTX 3...
# 0  2021-02-26  \nVTimes: проблемы, планы и финансовые показат...
# 0  2021-02-26  \nПредприниматель Андрей Андреев утверждает, ч...
#
#                                           link
# 0  https://habr.com/ru/news/t/544526/#comments
# 0  https://habr.com/ru/news/t/544518/#comments
# 0  https://habr.com/ru/news/t/544502/#comments
# 0  https://habr.com/ru/news/t/544496/#comments
# ...

# %%
EMAIL = ['natalie-1512@yandex.ru', 'natalia.s.yurchenko@gmail.com']
URL_1 = 'https://identityprotection.avast.com/v1/web/query/site-breaches/unauthorized-data'
params_1 = {
    'emailAddresses':EMAIL
}
headers = {'Vaar-Version': '0', 'Vaar-Header-App-Product-Name': 'hackcheck-web-avast', 'Vaar-Header-App-Build-Version':'1.0.0'}

# %%
import json

# %%
res_1 = requests.post(URL_1, json.dumps(params_1), headers=headers)

# %%
res_1.text
# Out:
# '{"breaches":{"16372":{"breachId":16372,"site":"bookmate.com","recordsCount":7775238,"description":"In July 2018, Bookmate was allegedly breached. The stolen data contains usernames, passwords, salts, email addresses and additional personal information. This data has been sold on at least one dark web market and is also being privately shared among several criminal networks.\\r\\n","publishDate":"2019-03-20T00:00:00Z","statistics":{"usernames":7775230,"passwords":2547574,"emails":3822191}},"17609":{"breachId":17609,"site":"vk.com","recordsCount":42536910,"description":"At some time in 2020, the Russian social networking website vKontakte was allegedly breached. The stolen data contains email addresses and additional personal information. This breach is being privately shared on the internet.","publishDate":"2020-05-21T00:00:00Z","statistics":{"usernames":0,"passwords":0,"emails":20549631}},"27550":{"breachId":27550,"site":"podgotovka.ru","recordsCount":46720,"description":"In Novembe
# ...

# %%
df = pd.DataFrame(json.loads(res_1.text)['breaches'])

# %%
df = df.transpose()
df
# Out:
#       breachId             site recordsCount  \
# 16372    16372     bookmate.com      7775238
# 17609    17609           vk.com     42536910
# 27550    27550    podgotovka.ru        46720
# 12          12           vk.com    110121799
# 4102      4102       yandex.com      1186559
# 16659    16659  livejournal.com     30485836
#
#                                              description  \
# 16372  In July 2018, Bookmate was allegedly breached....
# 17609  At some time in 2020, the Russian social netwo...
# 27550  In November 2020, a collection of over 23,000 ...
# 12     Popular Russian social networking platform VKo...
# 4102   In January 2014, Yandex's user database was al...
# 16659  In 2017, social network LiveJournal's database...
#
#                 publishDate                                         statistics
# 16372  2019-03-20T00:00:00Z  {'usernames': 7775230, 'passwords': 2547574, '...
# 17609  2020-05-21T00:00:00Z  {'usernames': 0, 'passwords': 0, 'emails': 205...
# ...

# %%
df['breachId']
# Out:
# 16372    16372
# 17609    17609
# 27550    27550
# 12          12
# 4102      4102
# 16659    16659
# Name: breachId, dtype: object

# %%
result_2 = pd.DataFrame(json.loads(res_1.text)['summary'])
result_2.transpose()
result_2
# Out:
#                           natalie-1512@yandex.ru natalia.s.yurchenko@gmail.com
# breaches  [16372, 17609, 27550, 12, 4102, 16659]                            []

# %%
a = json.loads(res_1.text)['data']
a
# Out:
# {'bookmate.com': {'natalie-1512@yandex.ru': [{'breachId': 16372,
#     'usernameBreached': True,
#     'passwordBreached': True}]},
#  'livejournal.com': {'natalie-1512@yandex.ru': [{'breachId': 16659,
#     'usernameBreached': True,
#     'passwordBreached': True}]},
#  'podgotovka.ru': {'natalie-1512@yandex.ru': [{'breachId': 27550,
#     'usernameBreached': True,
#     'passwordBreached': True}]},
#  'vk.com': {'natalie-1512@yandex.ru': [{'breachId': 17609,
#     'usernameBreached': True,
#     'passwordBreached': True},
#    {'breachId': 12, 'usernameBreached': True, 'passwordBreached': True}]},
#  'yandex.com': {'natalie-1512@yandex.ru': [{'breachId': 4102,
#     'usernameBreached': True,
#     'passwordBreached': True}]}}

# %%
final = {}
for each_site in a.values():
    for email, breaches in each_site.items():
        for breach in breaches:
            final[breach['breachId']] = email
email_and_id = pd.DataFrame(final.items())

# %%
email_and_id.columns = ['breachId', 'Email']
email_and_id['breachId']
# Out:
# 0    16372
# 1    16659
# 2    27550
# 3    17609
# 4       12
# 5     4102
# Name: breachId, dtype: int64

# %%
new = df.merge(email_and_id, on = 'breachId', how = 'inner')
new[['Email', 'publishDate', 'site', 'description']]
# Out:
#                     Email           publishDate             site  \
# 0  natalie-1512@yandex.ru  2019-03-20T00:00:00Z     bookmate.com
# 1  natalie-1512@yandex.ru  2020-05-21T00:00:00Z           vk.com
# 2  natalie-1512@yandex.ru  2020-12-10T00:00:00Z    podgotovka.ru
# 3  natalie-1512@yandex.ru  2016-10-29T00:00:00Z           vk.com
# 4  natalie-1512@yandex.ru  2017-04-28T00:00:00Z       yandex.com
# 5  natalie-1512@yandex.ru  2019-05-23T00:00:00Z  livejournal.com
#
#                                          description
# 0  In July 2018, Bookmate was allegedly breached....
# 1  At some time in 2020, the Russian social netwo...
# 2  In November 2020, a collection of over 23,000 ...
# 3  Popular Russian social networking platform VKo...
# 4  In January 2014, Yandex's user database was al...
# 5  In 2017, social network LiveJournal's database...
