# %%
import pandas as pd

# %%
data = pd.read_csv(r'C:\Users\vj0467\OneDrive - Sandvik\HomeShare\Documents\Yurchenko desktop copy\Marketing\Нетология_2020\HW\pyda-16-hw-1\power.csv')

# %%
filtered_values = data[ data.country.isin(['Lithuania', 'Latvia', 'Estonia'])  & (data.quantity > 0) & (data.year <= 2010) & (data.year >= 2005) & (data.category.isin(['4', '12', '21']))]
print(filtered_values.quantity.sum())
# Out:
# 240580.0

# %%
page_url = 'https://www.finanz.ru/valyuty/v-realnom-vremeni'

df = pd.read_html(page_url, attrs = {'class': 'quote_list'}, encoding='utf-8')[0]

# %%
df[df['Предложение'] != 'Предложение']
# Out:
#     Unnamed: 0            Рубль Предложение Спрос Предыдущее закрытие  \
# 0          NaN          GBP/RUB      998534     -              998688
# 1          NaN          EUR/RUB      888145     -              888145
# 2          NaN          USD/RUB      735000     -              733165
# 3          NaN          JPY/RUB       07073     -               07078
# 4          NaN          CNY/RUB      113413     -              113442
# 5          NaN          CHF/RUB      824375     -              825041
# 7          NaN          EUR/USD       12094     -               12154
# 8          NaN          EUR/GBP       08892     -               08892
# 9          NaN          EUR/JPY     1254800     -             1254800
# 10         NaN          EUR/CHF       10764     -               10795
# 12         NaN          USD/EUR       08279     -               08227
# 13         NaN          USD/GBP       07361     -               07362
# ...

# %%
ratings = pd.read_csv(r'C:\Users\vj0467\OneDrive - Sandvik\HomeShare\Documents\Yurchenko desktop copy\Marketing\Нетология_2020\HW\pyda-16-hw-1\ml-latest-small\ratings.csv')

# %%
movies = pd.read_csv(r'C:\Users\vj0467\OneDrive - Sandvik\HomeShare\Documents\Yurchenko desktop copy\Marketing\Нетология_2020\HW\pyda-16-hw-1\ml-latest-small\movies.csv')


best_movie = ratings[(ratings.rating == 5.0)].groupby('movieId').count().sort_values('rating', ascending=False)
joined = best_movie.merge(movies, on='movieId', how='left')
joined.head(1)
# Out:
#    movieId  userId  rating  timestamp                             title  \
# 0      318     153     153        153  Shawshank Redemption, The (1994)
#
#         genres
# 0  Crime|Drama
