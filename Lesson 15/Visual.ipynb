# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\vj0467\OneDrive - Sandvik\HomeShare\Documents\Yurchenko desktop copy\Marketing\Нетология_2020\HW\pyda-16-hw-1\supermarket sales\supermarket_sales - Sheet1.csv')

# %%
df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
product_by_gender = df.pivot_table(index = 'Product line', columns = 'Gender', values = 'Total', aggfunc = 'sum', fill_value = 0)
product_by_gender
# Out:
# Gender                      Female        Male
# Product line
# Electronic accessories  27102.0225  27235.5090
# Fashion accessories     30437.4000  23868.4950
# Food and beverages      33170.9175  22973.9265
# Health and beauty       18560.9865  30632.7525
# Home and lifestyle      30036.8775  23825.0355
# Sports and travel       28574.7210  26548.1055

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1. Дорогие покупки совершают реже, несмотря на то, что это члены программы лояльности

# %%
df['Total'][df['Customer type'] == 'Member'].plot(kind='hist', 
                   title='Spending distribution for Loyal Customers')

# %% [markdown]
# ## 2. В данном супермаркете женщины тратят больше на категории Fashion и Food&Bev, а мужчины тратят значительно больше в категории Health&Beauty

# %%
product_by_gender.plot(kind='bar', title='Product sales by gender',   rot = 80)

# %%
Google = pd.read_csv(r'C:\Users\vj0467\OneDrive - Sandvik\HomeShare\Documents\Yurchenko desktop copy\Marketing\Нетология_2020\HW\pyda-16-hw-1\Goole play\googleplaystore.csv')

# %%
Google
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
average_rating = Google.groupby('Category').mean()[['Rating']]
average_rating = average_rating.drop(index='1.9')
average_rating = average_rating.sort_values(['Rating'], ascending = False)
average_rating.sort_values(['Rating'], ascending = False)
# Out:
#                        Rating
# Category
# EVENTS               4.435556
# EDUCATION            4.389032
# ART_AND_DESIGN       4.358065
# BOOKS_AND_REFERENCE  4.346067
# PERSONALIZATION      4.335987
# PARENTING            4.300000
# GAME                 4.286326
# BEAUTY               4.278571
# HEALTH_AND_FITNESS   4.277104
# SHOPPING             4.259664
# SOCIAL               4.255598
# WEATHER              4.244000
# SPORTS               4.223511
# PRODUCTIVITY         4.211396
# HOUSE_AND_HOME       4.197368
# FAMILY               4.192272
# PHOTOGRAPHY          4.192114
# AUTO_AND_VEHICLES    4.190411
# MEDICAL              4.189143
# LIBRARIES_AND_DEMO   4.178462
# FOOD_AND_DRINK       4.166972
# COMMUNICATION        4.158537
# COMICS               4.155172
# NEWS_AND_MAGAZINES   4.132189
# FINANCE              4.131889
# ENTERTAINMENT        4.126174
# BUSINESS             4.121452
# TRAVEL_AND_LOCAL     4.109292
# LIFESTYLE            4.094904
# ...

# %% [markdown]
# ## 3. Самый низкий рейтинг (чуть ниже 4.0) у категории maps and navigation, самый высокий (около 4.4) - у категории Events. Разбег оценок небольшой. Нет ни 5, ни 2.

# %%
average_rating.plot(title='Средний рейтинг по категории', rot = 80)

# %% [markdown]
# ## 3. Самое большое количество рецензий написано для категории Game. Категории Communication, Social, Tools, Famiiy  вошли в ТОП5.

# %%
Google['Reviews'] = pd.to_numeric(Google['Reviews'], errors = 'coerce')
reviews_data = Google.groupby('Category').sum()[['Reviews']]
reviews_data = reviews_data.sort_values(['Reviews'], ascending = False)
reviews_data
# Out:
#                           Reviews
# Category
# GAME                 1.585422e+09
# COMMUNICATION        8.154623e+08
# SOCIAL               6.212414e+08
# FAMILY               4.102263e+08
# TOOLS                2.731850e+08
# PHOTOGRAPHY          2.135166e+08
# SHOPPING             1.150412e+08
# PRODUCTIVITY         1.141170e+08
# VIDEO_PLAYERS        1.103802e+08
# PERSONALIZATION      8.934614e+07
# SPORTS               7.083017e+07
# TRAVEL_AND_LOCAL     6.261792e+07
# ENTERTAINMENT        5.917815e+07
# NEWS_AND_MAGAZINES   5.440086e+07
# EDUCATION            3.959579e+07
# HEALTH_AND_FITNESS   3.789374e+07
# MAPS_AND_NAVIGATION  3.065925e+07
# BOOKS_AND_REFERENCE  2.195907e+07
# FINANCE              1.755073e+07
# WEATHER              1.460474e+07
# BUSINESS             1.395455e+07
# LIFESTYLE            1.288278e+07
# FOOD_AND_DRINK       8.883330e+06
# DATING               7.291278e+06
# HOUSE_AND_HOME       3.976385e+06
# COMICS               3.383276e+06
# ...

# %%
reviews_data.loc[['GAME', 'COMMUNICATION', 'SOCIAL', 'FAMILY', 'TOOLS']].plot(kind='bar', 
                                                                  title='TOP 5 most reviewed categories')
