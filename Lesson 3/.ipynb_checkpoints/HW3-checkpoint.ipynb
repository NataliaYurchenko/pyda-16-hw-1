# %%
documents = [
{'type': 'passport', 'number': '2207 876234', 'name': 'Василий Гупкин'},
{'type': 'invoice', 'number': '11-2', 'name': 'Геннадий Покемонов'},
{'type': 'insurance', 'number': '10006', 'name': 'Аристарх Павлов'}
]

directories = {
'1': ['2207 876234', '11-2'],
'2': ['10006'],
'3': []
}
name = []
def doc_owner(documents):
    user_input = input('Введите номер документа: ')
    for line in documents:
        if user_input == line['number']:
            name = line['name']
            return name
    return 'Документ не найден в базе'
 
number = []

def shelf_num(directories):
    user_input_1 = input('Введите номер документа: ')
    for shelf in directories.keys():
        #for number in directories[shelf]:
            if user_input_1 in list(directories[shelf]):
                return shelf
    return 'Документ не найден в базе'
 


res = {}
def copy_everything_but_target_key (directories, target_key):
    for key, value in directories.items():
        if key != target_key:
            res[key] = value
    return 'Полка удалена. Текущий перечень полок '+ str(list(res.keys()))
def show_message(directories):
        return 'На полке есть документы, удалите их перед удалением полки. Текущий перечень полок: ' + str(list(directories.keys()))

def shelf_1(directories):
    user_input_3 = input('Введите номер полки: ')
    key = user_input_3
    if len(directories[key]) == 0:
        return (copy_everything_but_target_key(directories, key))
    else:
        return (show_message(directories))
            
                        

def find_directory_by_docid(docid, directories):
    for shelves in directories.keys():
        if docid in directories[shelves]:
            return shelves
        

def full_information(documents, directories):
    for line in documents:
        
            print('№: ', line['number'], 'тип: ', line['type'], 'владелец: ', line['name'], 'полка хранения: ', find_directory_by_docid(line['number'], directories))



new_directory = {}
def new_shelf (directories, new_key):
    directories[new_key] = []
    return 'Полка добавлена. Текущий перечень полок: ' + str(list(directories.keys()))
def show_message_1(directories):
    return 'Такая полка уже существует. Текущий перечень полок: ' + str(list(directories.keys()))

def add_shelf(directories):
    user_input_4 = input('Введите номер полки: ')
    key = user_input_4
    if key not in directories.keys():
        return (new_shelf(directories, key))
    else:
        return (show_message_1(directories))



def main(directories, documents):
    while True:
        user_input = input('Введите команду ')
        if user_input == 'p':
            print(doc_owner(documents))
        elif user_input == 's':
            print(shelf_num(directories))
        elif user_input == 'l':
            print (full_information(documents, directories))
        elif user_input == 'as':
            print(add_shelf(directories))
        elif user_input == 'ds':
            print(shelf_1(directories))
            break
main(directories, documents)
# Out:
# Введите команду as
# Введите номер полки: 3
# Такая полка уже существует. Текущий перечень полок: ['1', '2', '3']
# Введите команду ds
# Введите номер полки: 1
# На полке есть документы, удалите их перед удалением полки. Текущий перечень полок: ['1', '2', '3']
